# %%
import pandas as pd

# Load datasets
movies = pd.read_csv('../data/tmdb_5000_movies.csv')
tracks = pd.read_csv('../data/tracks.csv')

#Datasets that i am working with
print("Movies shape:", movies.shape)
print("Tracks shape:", tracks.shape)
movies.head()
# Out:
# Movies shape: (4803, 20)
# Tracks shape: (114000, 21)
#       budget                                             genres  \
# 0  237000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 1  300000000  [{"id": 12, "name": "Adventure"}, {"id": 14, "...
# 2  245000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 3  250000000  [{"id": 28, "name": "Action"}, {"id": 80, "nam...
# 4  260000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
#
#                                        homepage      id  \
# 0                   http://www.avatarmovie.com/   19995
# 1  http://disney.go.com/disneypictures/pirates/     285
# 2   http://www.sonypictures.com/movies/spectre/  206647
# 3            http://www.thedarkknightrises.com/   49026
# 4          http://movies.disney.com/john-carter   49529
#
#                                             keywords original_language  \
# 0  [{"id": 1463, "name": "culture clash"}, {"id":...                en
# 1  [{"id": 270, "name": "ocean"}, {"id": 726, "na...                en
# 2  [{"id": 470, "name": "spy"}, {"id": 818, "name...                en
# 3  [{"id": 849, "name": "dc comics"}, {"id": 853,...                en
# 4  [{"id": 818, "name": "based on novel"}, {"id":...                en
#
#                              original_title  \
# 0                                    Avatar
# 1  Pirates of the Caribbean: At World's End
# 2                                   Spectre
# 3                     The Dark Knight Rises
# 4                               John Carter
#
#                                             overview  popularity  \
# 0  In the 22nd century, a paraplegic Marine is di...  150.437577
# 1  Captain Barbossa, long believed to be dead, ha...  139.082615
# 2  A cryptic message from Bond’s past sends him o...  107.376788
# 3  Following the death of District Attorney Harve...  112.312950
# 4  John Carter is a war-weary, former military ca...   43.926995
#
#                                 production_companies  \
# 0  [{"name": "Ingenious Film Partners", "id": 289...
# 1  [{"name": "Walt Disney Pictures", "id": 2}, {"...
# 2  [{"name": "Columbia Pictures", "id": 5}, {"nam...
# 3  [{"name": "Legendary Pictures", "id": 923}, {"...
# 4        [{"name": "Walt Disney Pictures", "id": 2}]
#
#                                 production_countries release_date     revenue  \
# 0  [{"iso_3166_1": "US", "name": "United States o...   2009-12-10  2787965087
# 1  [{"iso_3166_1": "US", "name": "United States o...   2007-05-19   961000000
# 2  [{"iso_3166_1": "GB", "name": "United Kingdom"...   2015-10-26   880674609
# 3  [{"iso_3166_1": "US", "name": "United States o...   2012-07-16  1084939099
# 4  [{"iso_3166_1": "US", "name": "United States o...   2012-03-07   284139100
#
#    runtime                                   spoken_languages    status  \
# 0    162.0  [{"iso_639_1": "en", "name": "English"}, {"iso...  Released
# 1    169.0           [{"iso_639_1": "en", "name": "English"}]  Released
# 2    148.0  [{"iso_639_1": "fr", "name": "Fran\u00e7ais"},...  Released
# 3    165.0           [{"iso_639_1": "en", "name": "English"}]  Released
# 4    132.0           [{"iso_639_1": "en", "name": "English"}]  Released
#
#                                           tagline  \
# 0                     Enter the World of Pandora.
# 1  At the end of the world, the adventure begins.
# 2                           A Plan No One Escapes
# 3                                 The Legend Ends
# 4            Lost in our world, found in another.
#
#                                       title  vote_average  vote_count
# 0                                    Avatar           7.2       11800
# 1  Pirates of the Caribbean: At World's End           6.9        4500
# 2                                   Spectre           6.3        4466
# 3                     The Dark Knight Rises           7.6        9106
# 4                               John Carter           6.1        2124

# %%
print("Movie columns:")
print(movies.columns.tolist())

print("\nTrack columns:")
print(tracks.columns.tolist())
# Out:
# Movie columns:
# ['budget', 'genres', 'homepage', 'id', 'keywords', 'original_language', 'original_title', 'overview', 'popularity', 'production_companies', 'production_countries', 'release_date', 'revenue', 'runtime', 'spoken_languages', 'status', 'tagline', 'title', 'vote_average', 'vote_count']
#
# Track columns:
# ['Unnamed: 0', 'track_id', 'artists', 'album_name', 'track_name', 'popularity', 'duration_ms', 'explicit', 'danceability', 'energy', 'key', 'loudness', 'mode', 'speechiness', 'acousticness', 'instrumentalness', 'liveness', 'valence', 'tempo', 'time_signature', 'track_genre']

# %%
# Keeping only useful columns
movies = movies[['title', 'genres', 'vote_average', 'overview']]
tracks = tracks[['track_name', 'artists', 'track_genre', 'valence', 'energy', 'tempo', 'danceability']]

print("Movies cleaned:")
print(movies.head(3))
print("\nTracks cleaned:")
print(tracks.head(3))
# Out:
# Movies cleaned:
#                                       title  \
# 0                                    Avatar
# 1  Pirates of the Caribbean: At World's End
# 2                                   Spectre
#
#                                               genres  vote_average  \
# 0  [{"id": 28, "name": "Action"}, {"id": 12, "nam...           7.2
# 1  [{"id": 12, "name": "Adventure"}, {"id": 14, "...           6.9
# 2  [{"id": 28, "name": "Action"}, {"id": 12, "nam...           6.3
#
#                                             overview
# 0  In the 22nd century, a paraplegic Marine is di...
# 1  Captain Barbossa, long believed to be dead, ha...
# 2  A cryptic message from Bond’s past sends him o...
#
# Tracks cleaned:
#          track_name                 artists track_genre  valence  energy  \
# 0            Comedy             Gen Hoshino    acoustic    0.715   0.461
# 1  Ghost - Acoustic            Ben Woodward    acoustic    0.267   0.166
# 2    To Begin Again  Ingrid Michaelson;ZAYN    acoustic    0.120   0.359
#
#     tempo  danceability
# 0  87.917         0.676
# 1  77.489         0.420
# 2  76.332         0.438

# %%
# Define mood profiles
mood_profiles = {
    'happy':     {'valence': 0.8, 'energy': 0.7, 'danceability': 0.7, 'tempo': 120},
    'sad':       {'valence': 0.2, 'energy': 0.3, 'danceability': 0.3, 'tempo': 70},
    'energetic': {'valence': 0.7, 'energy': 0.9, 'danceability': 0.8, 'tempo': 140},
    'chill':     {'valence': 0.5, 'energy': 0.3, 'danceability': 0.4, 'tempo': 90},
    'romantic':  {'valence': 0.6, 'energy': 0.4, 'danceability': 0.5, 'tempo': 100},
}

# Define which movie genres match each mood
mood_genres = {
    'happy':     ['Comedy', 'Animation', 'Family'],
    'sad':       ['Drama', 'Romance'],
    'energetic': ['Action', 'Thriller', 'Adventure'],
    'chill':     ['Documentary', 'Music', 'Fantasy'],
    'romantic':  ['Romance', 'Drama', 'Comedy'],
}

print("Mood profiles defined!")
print(list(mood_profiles.keys()))
# Out:
# Mood profiles defined!
# ['happy', 'sad', 'energetic', 'chill', 'romantic']

# %%
import pandas as pd
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics.pairwise import cosine_similarity
import numpy as np

# Normalize the track audio features
scaler = MinMaxScaler()
track_features = tracks[['valence', 'energy', 'danceability', 'tempo']].copy()
track_features_scaled = scaler.fit_transform(track_features)

print("Tracks scaled successfully!")
print("Shape:", track_features_scaled.shape)
# Out:
# Tracks scaled successfully!
# Shape: (114000, 4)

# %%
def recommend_songs(mood, n=5):
    # Get the mood profile
    mood_vector = pd.DataFrame([mood_profiles[mood]])
    mood_vector_scaled = scaler.transform(mood_vector)
    
    # Calculate cosine similarity between mood and all tracks
    similarities = cosine_similarity(mood_vector_scaled, track_features_scaled)
    
    # Get top n most similar tracks
    top_indices = similarities[0].argsort()[-n:][::-1]
    
    results = tracks.iloc[top_indices][['track_name', 'artists', 'track_genre']].copy()
    results['similarity'] = similarities[0][top_indices]
    
    return results.reset_index(drop=True)

# Test it!
print("Testing happy mood:")
print(recommend_songs('happy'))
# Out:
# Testing happy mood:
#                   track_name  \
# 0  Sentada Malvada - Ao vivo
# 1             Juliet & Romeo
# 2             Juliet & Romeo
# 3             Juliet & Romeo
# 4              Como Las Olas
#
#                                              artists track_genre  similarity
# 0                                          Kamisa 10      pagode    0.999999
# 1                           Martin Solveig;Roy Woods       disco    0.999982
# 2                           Martin Solveig;Roy Woods       house    0.999982
# 3                           Martin Solveig;Roy Woods         edm    0.999982
# 4  Antonio Garcia Isaac;Roberto Aguilar;Felipe Gu...      guitar    0.999977

# %%
def recommend_songs(mood, n=5):
    mood_vector = pd.DataFrame([mood_profiles[mood]])
    mood_vector_scaled = scaler.transform(mood_vector)
    
    similarities = cosine_similarity(mood_vector_scaled, track_features_scaled)
    
    top_indices = similarities[0].argsort()[-50:][::-1]
    
    results = tracks.iloc[top_indices][['track_name', 'artists', 'track_genre']].copy()
    results['similarity'] = similarities[0][top_indices]
    
    # Remove duplicate track names
    results = results.drop_duplicates(subset='track_name')
    
    return results.head(n).reset_index(drop=True)

# Test all moods
for mood in mood_profiles.keys():
    print(f"\n--- {mood.upper()} ---")
    print(recommend_songs(mood))
# Out:
# --- HAPPY ---
#                   track_name  \
# 0  Sentada Malvada - Ao vivo
# 1             Juliet & Romeo
# 2              Como Las Olas
# 3                  Deep Kiss
# 4           Vámonos De Viaje
#
#                                              artists    track_genre  \
# 0                                          Kamisa 10         pagode
# 1                           Martin Solveig;Roy Woods          disco
# 2  Antonio Garcia Isaac;Roberto Aguilar;Felipe Gu...         guitar
# 3                                           Ten City  chicago-house
# 4                                    Bandalos Chinos       alt-rock
#
#    similarity
# 0    0.999999
# 1    0.999982
# 2    0.999977
# 3    0.999969
# 4    0.999950
#
# --- SAD ---
#                                track_name                       artists  \
# 0                      Trapped in My Mind                       Adam Oh
# 1                            Tunna kläder  Daniel Adams-Ray;Erik Lundin
# 2  Baby Volta pro Seu Nego (Versão Grave)        Os Barões Da Pisadinha
# 3                                    GOAT              Sidhu Moose Wala
# 4                                Konuşmak                  Yasemin Mori
#
#   track_genre  similarity
# 0         sad    0.999952
# 1     swedish    0.999936
# 2       forro    0.999923
# 3     hip-hop    0.999909
# 4      j-rock    0.999902
#
# --- ENERGETIC ---
#                            track_name                      artists  \
# 0                         Premonition             FooR;Eddie Craig
# 1  De Virada É Mais Gostoso - Ao Vivo                     Janaynna
# 2      Earthday ( John Tejada Remix )    Karsten Pflum;John Tejada
# 3               Lola Loves Jacky Cola  Die Gerchli;Kings of Günter
# 4                               Lmnop            Koo Koo Kanga Roo
#
#   track_genre  similarity
# 0      groove    0.999976
# 1   sertanejo    0.999973
# 2         idm    0.999970
# 3       party    0.999963
# 4        kids    0.999957
#
# --- CHILL ---
#                   track_name                                 artists  \
# 0  Hoy Ya No Hicimos el Amor  Edwin Luna y La Trakalosa de Monterrey
# 1     Medallita De La Suerte        Alfredo De Angelis;Oscar Larroca
# 2             Cruise Control                      Sheba Potts-Wright
# 3    I'm into Something Good                        Herman's Hermits
# 4   Frank Mills - Remastered                          The Lemonheads
#
#   track_genre  similarity
# 0       r-n-b    0.999973
# 1       tango    0.999967
# 2       blues    0.999963
# 3  rockabilly    0.999962
# 4   power-pop    0.999931
#
# --- ROMANTIC ---
#                               track_name  \
# 0                             Dark Skies
# 1                         C'Est Comme Ca
# 2              De Pisadinha em Pisadinha
# 3  Night Away (Dance) (feat. Tion Wayne)
# 4                         Синий платочек
#
#                                              artists track_genre  similarity
# 0                                      Alison Krauss   bluegrass    0.999983
# 1                                    Amadou & Mariam       blues    0.999974
# 2                                        Paulo Pires       forro    0.999964
# 3                                 A1 x J1;Tion Wayne       chill    0.999947
# 4  Klavdiya Shulzhenko;Юрий Силантьев;Эстрадно-си...     romance    0.999933

# %%
# Filter to English tracks only
english_genres = [
    'pop', 'rock', 'indie', 'jazz', 'blues', 'country', 'hip-hop', 
    'r-n-b', 'soul', 'disco', 'edm', 'house', 'electronic', 'folk',
    'classical', 'metal', 'punk', 'alternative', 'dance', 'kids',
    'comedy', 'acoustic', 'groove', 'party', 'sad', 'chill'
]

tracks_english = tracks[tracks['track_genre'].isin(english_genres)].copy()
track_features_english = tracks_english[['valence', 'energy', 'danceability', 'tempo']].copy()
track_features_english_scaled = scaler.fit_transform(track_features_english)

print("English tracks:", len(tracks_english))
# Out:
# English tracks: 26000

# %%
def recommend_songs(mood, n=5):
    mood_vector = pd.DataFrame([mood_profiles[mood]])
    mood_vector_scaled = scaler.transform(mood_vector)
    
    similarities = cosine_similarity(mood_vector_scaled, track_features_english_scaled)
    
    top_indices = similarities[0].argsort()[-50:][::-1]
    
    results = tracks_english.iloc[top_indices][['track_name', 'artists', 'track_genre']].copy()
    results['similarity'] = similarities[0][top_indices]
    results = results.drop_duplicates(subset='track_name')
    
    return results.head(n).reset_index(drop=True)

# Test happy mood
print(recommend_songs('happy'))
# Out:
#           track_name                   artists  track_genre  similarity
# 0     Juliet & Romeo  Martin Solveig;Roy Woods        house    0.999982
# 1   Vámonos De Viaje           Bandalos Chinos  alternative    0.999950
# 2  The Hamster Dance                  DJ Krazy         kids    0.999941
# 3       Pan Mechanik          Denis Impulsywni        disco    0.999912
# 4             Melanż                   MiłyPan        disco    0.999877

# %%
def is_english(text):
    if not isinstance(text, str):
        return False
    try:
        text.encode('ascii')
        return True
    except UnicodeEncodeError:
        return False

# Filter tracks where both track name and artist are ASCII (English)
tracks_english = tracks[
    tracks['track_name'].apply(is_english) & 
    tracks['artists'].apply(is_english)
].copy()

track_features_english = tracks_english[['valence', 'energy', 'danceability', 'tempo']].copy()
track_features_english_scaled = scaler.fit_transform(track_features_english)

print("English tracks:", len(tracks_english))
# Out:
# English tracks: 93227

# %%
print(recommend_songs('happy'))
# Out:
#                   track_name  \
# 0  Sentada Malvada - Ao vivo
# 1             Juliet & Romeo
# 2              Como Las Olas
# 3                  Deep Kiss
# 4          The Hamster Dance
#
#                                              artists    track_genre  \
# 0                                          Kamisa 10         pagode
# 1                           Martin Solveig;Roy Woods          disco
# 2  Antonio Garcia Isaac;Roberto Aguilar;Felipe Gu...         guitar
# 3                                           Ten City  chicago-house
# 4                                           DJ Krazy           kids
#
#    similarity
# 0    0.999999
# 1    0.999982
# 2    0.999977
# 3    0.999969
# 4    0.999941

# %%
def recommend_songs(mood, n=5):
    mood_vector = pd.DataFrame([mood_profiles[mood]])
    mood_vector_scaled = scaler.transform(mood_vector)
    
    similarities = cosine_similarity(mood_vector_scaled, track_features_english_scaled)
    
    top_indices = similarities[0].argsort()[-50:][::-1]
    
    results = tracks_english.iloc[top_indices][['track_name', 'artists', 'track_genre']].copy()
    results['similarity'] = similarities[0][top_indices]
    results = results.drop_duplicates(subset='track_name')
    
    return results.head(n).reset_index(drop=True)

print(recommend_songs('happy'))
# Out:
#                   track_name  \
# 0  Sentada Malvada - Ao vivo
# 1             Juliet & Romeo
# 2              Como Las Olas
# 3                  Deep Kiss
# 4          The Hamster Dance
#
#                                              artists    track_genre  \
# 0                                          Kamisa 10         pagode
# 1                           Martin Solveig;Roy Woods          disco
# 2  Antonio Garcia Isaac;Roberto Aguilar;Felipe Gu...         guitar
# 3                                           Ten City  chicago-house
# 4                                           DJ Krazy           kids
#
#    similarity
# 0    0.999999
# 1    0.999982
# 2    0.999977
# 3    0.999969
# 4    0.999941

# %%
print("Sentada Malvada - Ao vivo".encode('ascii'))
print(tracks_english[tracks_english['track_name'] == 'Sentada Malvada - Ao vivo'])
# Out:
# b'Sentada Malvada - Ao vivo'
#                       track_name    artists track_genre  valence  energy  \
# 77230  Sentada Malvada - Ao vivo  Kamisa 10      pagode    0.864   0.755
#
#          tempo  danceability
# 77230  129.919         0.754

# %%
english_genres = [
    'pop', 'rock', 'indie', 'jazz', 'blues', 'country', 'hip-hop',
    'r-n-b', 'soul', 'disco', 'edm', 'house', 'electronic', 'folk',
    'classical', 'metal', 'punk', 'alternative', 'dance', 'kids',
    'comedy', 'acoustic', 'groove', 'party', 'sad', 'chill',
    'ambient', 'indie-pop', 'pop-film', 'power-pop', 'rockabilly',
    'singer-songwriter', 'sleep', 'study', 'summer', 'work-out'
]

tracks_english = tracks[tracks['track_genre'].isin(english_genres)].copy()
track_features_english = tracks_english[['valence', 'energy', 'danceability', 'tempo']].copy()
track_features_english_scaled = scaler.fit_transform(track_features_english)

print("Filtered tracks:", len(tracks_english))
print("Unique genres:", tracks_english['track_genre'].unique())
# Out:
# Filtered tracks: 34000
# Unique genres: <StringArray>
# [         'acoustic',       'alternative',           'ambient',
#              'blues',             'chill',         'classical',
#             'comedy',           'country',             'dance',
#              'disco',               'edm',        'electronic',
#               'folk',            'groove',           'hip-hop',
#              'house',         'indie-pop',             'indie',
#               'jazz',              'kids',             'metal',
#              'party',          'pop-film',               'pop',
#          'power-pop',              'punk',             'r-n-b',
#               'rock',        'rockabilly',               'sad',
#  'singer-songwriter',             'sleep',              'soul',
#              'study']
# Length: 34, dtype: str

# %%
print(recommend_songs('happy'))
# Out:
#           track_name                   artists  track_genre  similarity
# 0     Juliet & Romeo  Martin Solveig;Roy Woods        disco    0.999982
# 1   Vámonos De Viaje           Bandalos Chinos  alternative    0.999950
# 2  The Hamster Dance                  DJ Krazy         kids    0.999941
# 3       Pan Mechanik          Denis Impulsywni        disco    0.999912
# 4             Melanż                   MiłyPan        disco    0.999877

# %%
def is_english(text):
    if not isinstance(text, str):
        return False
    try:
        text.encode('ascii')
        return True
    except UnicodeEncodeError:
        return False

english_genres = [
    'pop', 'rock', 'indie', 'jazz', 'blues', 'country', 'hip-hop',
    'r-n-b', 'soul', 'disco', 'edm', 'house', 'electronic', 'folk',
    'classical', 'metal', 'punk', 'alternative', 'dance', 'kids',
    'comedy', 'acoustic', 'groove', 'party', 'sad', 'chill',
    'ambient', 'indie-pop', 'pop-film', 'power-pop', 'rockabilly',
    'singer-songwriter', 'sleep', 'study', 'summer', 'work-out'
]

tracks_english = tracks[
    tracks['track_genre'].isin(english_genres) &
    tracks['track_name'].apply(is_english) &
    tracks['artists'].apply(is_english)
].copy()

track_features_english = tracks_english[['valence', 'energy', 'danceability', 'tempo']].copy()
track_features_english_scaled = scaler.fit_transform(track_features_english)

print("Filtered tracks:", len(tracks_english))
# Out:
# Filtered tracks: 30802

# %%
def recommend_songs(mood, n=5):
    mood_vector = pd.DataFrame([mood_profiles[mood]])
    mood_vector_scaled = scaler.transform(mood_vector)
    
    similarities = cosine_similarity(mood_vector_scaled, track_features_english_scaled)
    
    top_indices = similarities[0].argsort()[-50:][::-1]
    
    results = tracks_english.iloc[top_indices][['track_name', 'artists', 'track_genre']].copy()
    results['similarity'] = similarities[0][top_indices]
    results = results.drop_duplicates(subset='track_name')
    
    return results.head(n).reset_index(drop=True)

print(recommend_songs('happy'))
# Out:
#                                           track_name  \
# 0                                     Juliet & Romeo
# 1                                  The Hamster Dance
# 2                                       Pan Mechanik
# 3  No Peace For The Wicked - 2008 re-mastered ver...
# 4                                             Jumper
#
#                     artists track_genre  similarity
# 0  Martin Solveig;Roy Woods         edm    0.999982
# 1                  DJ Krazy        kids    0.999941
# 2          Denis Impulsywni       disco    0.999912
# 3             The Only Ones   power-pop    0.999874
# 4   Rudimental;Kareen Lomax       house    0.999874

# %%
import subprocess
subprocess.run(['pip', 'install', 'langdetect'])
# Out:
# CompletedProcess(args=['pip', 'install', 'langdetect'], returncode=0)

# %%
from langdetect import detect

def is_english_lang(text):
    if not isinstance(text, str):
        return False
    try:
        return detect(text) == 'en'
    except:
        return False

# Filter using language detection on track name
tracks_english = tracks[
    tracks['track_name'].apply(is_english_lang)
].copy()

track_features_english = tracks_english[['valence', 'energy', 'danceability', 'tempo']].copy()
track_features_english_scaled = scaler.fit_transform(track_features_english)

print("English tracks:", len(tracks_english))
# Out:
# English tracks: 45408

# %%
tracks_english.to_csv('../data/tracks_english.csv', index=False)
print("Saved!")
# Out:
# Saved!

# %%
print(recommend_songs('happy'))
# Out:
#                                           track_name        artists  \
# 0                                  The Hamster Dance       DJ Krazy
# 1                                     the backstroke   Rei Harakami
# 2                              Clases De Cha Cha Chá  Ramon Marquez
# 3                           Whatever Makes You Happy       Ten City
# 4  No Peace For The Wicked - 2008 re-mastered ver...  The Only Ones
#
#      track_genre  similarity
# 0           kids    0.999941
# 1            idm    0.999940
# 2    rock-n-roll    0.999897
# 3  chicago-house    0.999877
# 4      power-pop    0.999874

# %%
for mood in mood_profiles.keys():
    print(f"\n--- {mood.upper()} ---")
    print(recommend_songs(mood))
# Out:
# --- HAPPY ---
#                                           track_name        artists  \
# 0                                  The Hamster Dance       DJ Krazy
# 1                                     the backstroke   Rei Harakami
# 2                              Clases De Cha Cha Chá  Ramon Marquez
# 3                           Whatever Makes You Happy       Ten City
# 4  No Peace For The Wicked - 2008 re-mastered ver...  The Only Ones
#
#      track_genre  similarity
# 0           kids    0.999941
# 1            idm    0.999940
# 2    rock-n-roll    0.999897
# 3  chicago-house    0.999877
# 4      power-pop    0.999874
#
# --- SAD ---
#                               track_name                        artists  \
# 0                     Trapped in My Mind                        Adam Oh
# 1                  YOU - Remastered 2022                 Eikichi Yazawa
# 2                      Wish You The Best  Culture Code;Caslow;Nina Sung
# 3  See This Way - Blue Potential Version                     Jeff Mills
# 4                       I Chose Violence                    iamjakehill
#
#       track_genre  similarity
# 0             sad    0.999952
# 1      rockabilly    0.999778
# 2         dubstep    0.999748
# 3  detroit-techno    0.999718
# 4             sad    0.999695
#
# --- ENERGETIC ---
#                                   track_name                    artists  \
# 0                                Premonition           FooR;Eddie Craig
# 1             Earthday ( John Tejada Remix )  Karsten Pflum;John Tejada
# 2  Therapist, 'I Love You', And Thanksgiving               Dov Davidoff
# 3  Skinny Dip (Komodo) [feat. Philip Strand]      Deepend;Philip Strand
# 4                  Don't Stop - 12" Club Mix                Freestylers
#
#   track_genre  similarity
# 0      groove    0.999976
# 1         idm    0.999970
# 2      comedy    0.999951
# 3  deep-house    0.999933
# 4   breakbeat    0.999928
#
# --- CHILL ---
#                             track_name           artists track_genre  \
# 0              I'm into Something Good  Herman's Hermits  rockabilly
# 1                   Watch What Happens      Chris Montez  rockabilly
# 2  Latest Trends (feat. Aitch) - Remix     A1 x J1;Aitch       chill
# 3                       Two Brown Eyes       Eddie Noack  honky-tonk
# 4                     Little By Little     Groove Armada    trip-hop
#
#    similarity
# 0    0.999962
# 1    0.999924
# 2    0.999913
# 3    0.999834
# 4    0.999701
#
# --- ROMANTIC ---
#                               track_name                          artists  \
# 0  Night Away (Dance) (feat. Tion Wayne)               A1 x J1;Tion Wayne
# 1                      It's Now or Never                    Elvis Presley
# 2                          Thiru Thiruda                 Sujatha;Srinivas
# 3      Rockin' Around The Christmas Tree                       Brenda Lee
# 4       Un Tropezón (with Sexteto Tango)  Roberto Goyeneche;Sexteto Tango
#
#   track_genre  similarity
# 0       chill    0.999947
# 1  rockabilly    0.999882
# 2       malay    0.999857
# 3  rockabilly    0.999846
# 4       tango    0.999838
